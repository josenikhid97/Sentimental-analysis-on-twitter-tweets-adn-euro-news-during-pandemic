# %%
# !pip install webdriver-manager

from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# [WDM] - Current google-chrome version is 83.0.4103
# [WDM] - Get LATEST driver version for 83.0.4103
# [WDM] - There is no [win32] chromedriver for browser 83.0.4103 in cache
# [WDM] - Get LATEST driver version for 83.0.4103
# [WDM] - Trying to download new driver from http://chromedriver.storage.googleapis.com/83.0.4103.39/chromedriver_win32.zip
# ...
# [WDM] - Driver has been saved in cache [C:\Users\wessa\.wdm\drivers\chromedriver\win32\83.0.4103.39]

# %%
import numpy as np
import mysql.connector
from sqlalchemy import create_engine
import pymysql
import json
import time
from datetime import date
from dateutil.parser import parse
from datetime import datetime
import pandas as pd
import requests
from bs4 import BeautifulSoup 
from tqdm import notebook
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
import datetime
import re
from datetime import timedelta
import glob
import os
import math
from random import randint
from tqdm import notebook

# %%
for i in range(1, 90):
    url = 'https://www.euronews.com/search?query=covid-19&p='+ str(i)
    print(url)
    driver.get(url)

    headline_tag = driver.find_elements_by_class_name('m-object__title__link')
    date_tag = driver.find_elements_by_class_name('m-object__publishedAt')


    headlines = [*map(lambda x: x.get_attribute("title"), headline_tag)]
    urls= [*map(lambda x: x.get_attribute("href"), headline_tag)]
    published_dates=[*map(lambda x: x.get_attribute("innerText"), date_tag)]
    articles_body=[]
    for url in urls:
        driver.get(url)
        article_tag=driver.find_elements_by_class_name('c-article-content')
        if len(article_tag) > 0:
            articles_body.append(article_tag[0].get_attribute("innerText"))
        else:
            articles_body.append("")

    search_cv=pd.DataFrame(
        {'headline': headlines,
         'published_date': published_dates,
         'link': urls,
         'content': articles_body
        })
    search_cv.to_excel('Euronews_covid-'+str(i)+'.xlsx')
# Out:
# https://www.euronews.com/search?query=covid-19&p=1
# https://www.euronews.com/search?query=covid-19&p=2
# https://www.euronews.com/search?query=covid-19&p=3
# https://www.euronews.com/search?query=covid-19&p=4
# https://www.euronews.com/search?query=covid-19&p=5
# https://www.euronews.com/search?query=covid-19&p=6
# https://www.euronews.com/search?query=covid-19&p=7
# https://www.euronews.com/search?query=covid-19&p=8
# https://www.euronews.com/search?query=covid-19&p=9
# https://www.euronews.com/search?query=covid-19&p=10
# https://www.euronews.com/search?query=covid-19&p=11
# https://www.euronews.com/search?query=covid-19&p=12
# https://www.euronews.com/search?query=covid-19&p=13
# https://www.euronews.com/search?query=covid-19&p=14
# https://www.euronews.com/search?query=covid-19&p=15
# https://www.euronews.com/search?query=covid-19&p=16
# https://www.euronews.com/search?query=covid-19&p=17
# https://www.euronews.com/search?query=covid-19&p=18
# ...
